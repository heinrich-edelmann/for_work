# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tkinter as tk

# %%
pd.set_option('display.max_rows', 20) # changing the default number of rows that are shown in VSCode

# %%
preisetabelle_original = pd.read_excel("Aufgabe2_Preisinformation.xlsx")
preisetabelle_original
# Out:
#     Unnamed: 0              Unnamed: 1    Unnamed: 2  Unnamed: 3
# 0          NaN                     NaN           NaN         NaN  \
# 1          NaN              Bundesland  Kostenfaktor         NaN
# 2          NaN       Baden-Württemberg           1.5         NaN
# 3          NaN                  Bayern           1.7         NaN
# 4          NaN                  Berlin           2.1         NaN
# 5          NaN             Brandenburg           1.1         NaN
# 6          NaN                  Bremen           1.2         NaN
# 7          NaN                 Hamburg           2.5         NaN
# 8          NaN                  Hessen           1.3         NaN
# 9          NaN  Mecklenburg-Vorpommern           0.9         NaN
# 10         NaN           Niedersachsen             1         NaN
# 11         NaN     Nordrhein-Westfalen           1.1         NaN
# 12         NaN         Rheinland-Pfalz             1         NaN
# 13         NaN                Saarland           0.7         NaN
# 14         NaN                 Sachsen           0.7         NaN
# 15         NaN          Sachsen-Anhalt           0.6         NaN
# 16         NaN      Schleswig-Holstein           1.4         NaN
# 17         NaN               Thüringen           0.6         NaN
#
#             Unnamed: 4    Unnamed: 5  Unnamed: 6              Unnamed: 7
# 0                  NaN           NaN         NaN                     NaN  \
# 1        Stadt vs Land  Kostenfaktor         NaN  Weitere Kostenfaktoren
# 2                 Land             1         NaN           QM-Grundstück
# 3                Stadt             2         NaN           QM-Wohnfläche
# 4                  NaN           NaN         NaN   Geplant von Architekt
# 5          Ausstattung  Kostenfaktor         NaN                  Makler
# 6               Rohbau           0.5         NaN           Denkmalschutz
# 7     Sanierungsbedarf           0.8         NaN                 Baujahr
# 8   Renovierungsbedarf           0.9         NaN                     NaN
# 9              Einfach             1         NaN                     NaN
# 10             Gehoben             2         NaN                     NaN
# 11                 NaN           NaN         NaN                     NaN
# 12             Hausart  Kostenfaktor         NaN                     NaN
# 13     Einfamilienhaus             1         NaN                     NaN
# 14    Doppelhaushälfte           0.8         NaN                     NaN
# 15    Mehrfamilienhaus           0.7         NaN                     NaN
# 16                 NaN           NaN         NaN                     NaN
# 17                 NaN           NaN         NaN                     NaN
#
#    Unnamed: 8                 Unnamed: 9
# 0         NaN                        NaN
# 1       Preis                    Einheit
# 2         160                     pro m²
# 3        2500                     pro m²
# 4          20             Aufschlag in %
# 5          20             Aufschlag in %
# 6          25           Reduzierung in %
# 7         0.1  Reduzierung in % pro Jahr
# 8         NaN                        NaN
# 9         NaN                        NaN
# 10        NaN                        NaN
# 11        NaN                        NaN
# 12        NaN                        NaN
# 13        NaN                        NaN
# 14        NaN                        NaN
# 15        NaN                        NaN
# 16        NaN                        NaN
# 17        NaN                        NaN

# %%
preisetabelle_renamed = preisetabelle_original.rename(columns=preisetabelle_original.iloc[1])
pt = preisetabelle_renamed.drop(preisetabelle_renamed.index[1])
ptt = pt.drop(pt.index[0]).reset_index()
preisetabelle = ptt.drop(list(ptt)[0:2], axis=1)
preisetabelle
# Out:
#                 Bundesland Kostenfaktor  NaN       Stadt vs Land
# 0        Baden-Württemberg          1.5  NaN                Land  \
# 1                   Bayern          1.7  NaN               Stadt
# 2                   Berlin          2.1  NaN                 NaN
# 3              Brandenburg          1.1  NaN         Ausstattung
# 4                   Bremen          1.2  NaN              Rohbau
# 5                  Hamburg          2.5  NaN    Sanierungsbedarf
# 6                   Hessen          1.3  NaN  Renovierungsbedarf
# 7   Mecklenburg-Vorpommern          0.9  NaN             Einfach
# 8            Niedersachsen            1  NaN             Gehoben
# 9      Nordrhein-Westfalen          1.1  NaN                 NaN
# 10         Rheinland-Pfalz            1  NaN             Hausart
# 11                Saarland          0.7  NaN     Einfamilienhaus
# 12                 Sachsen          0.7  NaN    Doppelhaushälfte
# 13          Sachsen-Anhalt          0.6  NaN    Mehrfamilienhaus
# 14      Schleswig-Holstein          1.4  NaN                 NaN
# 15               Thüringen          0.6  NaN                 NaN
#
#     Kostenfaktor  NaN Weitere Kostenfaktoren Preis                    Einheit
# 0              1  NaN          QM-Grundstück   160                     pro m²
# 1              2  NaN          QM-Wohnfläche  2500                     pro m²
# 2            NaN  NaN  Geplant von Architekt    20             Aufschlag in %
# 3   Kostenfaktor  NaN                 Makler    20             Aufschlag in %
# 4            0.5  NaN          Denkmalschutz    25           Reduzierung in %
# 5            0.8  NaN                Baujahr   0.1  Reduzierung in % pro Jahr
# 6            0.9  NaN                    NaN   NaN                        NaN
# 7              1  NaN                    NaN   NaN                        NaN
# 8              2  NaN                    NaN   NaN                        NaN
# 9            NaN  NaN                    NaN   NaN                        NaN
# 10  Kostenfaktor  NaN                    NaN   NaN                        NaN
# 11             1  NaN                    NaN   NaN                        NaN
# 12           0.8  NaN                    NaN   NaN                        NaN
# 13           0.7  NaN                    NaN   NaN                        NaN
# 14           NaN  NaN                    NaN   NaN                        NaN
# 15           NaN  NaN                    NaN   NaN                        NaN

# %%
BundK = preisetabelle.iloc[0:16,0:2].set_index("Bundesland")
BundK
# Out:
#                        Kostenfaktor
# Bundesland
# Baden-Württemberg               1.5
# Bayern                          1.7
# Berlin                          2.1
# Brandenburg                     1.1
# Bremen                          1.2
# Hamburg                         2.5
# Hessen                          1.3
# Mecklenburg-Vorpommern          0.9
# Niedersachsen                     1
# Nordrhein-Westfalen             1.1
# Rheinland-Pfalz                   1
# Saarland                        0.7
# Sachsen                         0.7
# Sachsen-Anhalt                  0.6
# Schleswig-Holstein              1.4
# Thüringen                       0.6

# %%
SLundK = preisetabelle.iloc[0:2,3:5].set_index("Stadt vs Land")
SLundK
# Out:
#               Kostenfaktor
# Stadt vs Land
# Land                     1
# Stadt                    2

# %%
T1AundK = preisetabelle.iloc[3:8,3:5]

AundK = T1AundK.rename(columns=T1AundK.iloc[0]).drop(T1AundK.index[0]).reset_index().drop(["index"], axis = 1).set_index("Ausstattung")
AundK
# Out:
#                    Kostenfaktor
# Ausstattung
# Rohbau                      0.5
# Sanierungsbedarf            0.8
# Renovierungsbedarf          0.9
# Einfach                       1

# %%
T1HundK = preisetabelle.iloc[10:14,3:5]
HundK = T1HundK.rename(columns=T1HundK.iloc[0]).drop(T1HundK.index[0]).reset_index().drop(["index"], axis = 1).set_index("Hausart")
HundK
# Out:
#                  Kostenfaktor
# Hausart
# Einfamilienhaus             1
# Doppelhaushälfte          0.8
# Mehrfamilienhaus          0.7

# %%
WKproPE = preisetabelle.iloc[0:6,6:8].set_index("Weitere Kostenfaktoren")
WKproPE
# Out:
#                        Preis
# Weitere Kostenfaktoren
# QM-Grundstück            160
# QM-Wohnfläche           2500
# Geplant von Architekt     20
# Makler                    20
# Denkmalschutz             25
# Baujahr                  0.1

# %% [markdown]
# #### ab hier sind die Tabelle fertig verarbeitet und getrennt von einander

# %%
BundK # Bundesland und Kostenfaktor
# Out:
#                        Kostenfaktor
# Bundesland
# Baden-Württemberg               1.5
# Bayern                          1.7
# Berlin                          2.1
# Brandenburg                     1.1
# Bremen                          1.2
# Hamburg                         2.5
# Hessen                          1.3
# Mecklenburg-Vorpommern          0.9
# Niedersachsen                     1
# Nordrhein-Westfalen             1.1
# Rheinland-Pfalz                   1
# Saarland                        0.7
# Sachsen                         0.7
# Sachsen-Anhalt                  0.6
# Schleswig-Holstein              1.4
# Thüringen                       0.6

# %%
SLundK # StadtvsLand und Kostenfaktor
# Out:
#               Kostenfaktor
# Stadt vs Land
# Land                     1
# Stadt                    2

# %%
SLundK
# Out:
#               Kostenfaktor
# Stadt vs Land
# Land                     1
# Stadt                    2

# %%
AundK # Ausstattung und Kostenfaktor
# Out:
#                    Kostenfaktor
# Ausstattung
# Rohbau                      0.5
# Sanierungsbedarf            0.8
# Renovierungsbedarf          0.9
# Einfach                       1

# %%
HundK # Hausart und Kostenfaktor
# Out:
#                  Kostenfaktor
# Hausart
# Einfamilienhaus             1
# Doppelhaushälfte          0.8
# Mehrfamilienhaus          0.7

# %%
WKproPE # Weitere Kostenfaktoren pro Preis und Einheit
# Out:
#                        Preis
# Weitere Kostenfaktoren
# QM-Grundstück            160
# QM-Wohnfläche           2500
# Geplant von Architekt     20
# Makler                    20
# Denkmalschutz             25
# Baujahr                  0.1

# %%
preis_QM_Wohnfläche_nachTabelle = float(WKproPE.loc["QM-Wohnfläche"])    
preis_QM_Wohnfläche_nachTabelle
# Out:
# C:\Users\hhhme\AppData\Local\Temp\ipykernel_13948\521521627.py:1: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   preis_QM_Wohnfläche_nachTabelle = float(WKproPE.loc["QM-Wohnfläche"])
# 2500.0

# %% [markdown]
# ### Die Benutzoberfläche an sich

# %%
import tkinter as tk
import tkinter.messagebox


window = tk.Tk()
window.geometry("500x200")
window.title("Hauspreisrechner")

#Erstellung meiner Arbeitswindow:
labelListboxGrundstück = tk.Label(window, text="Grundstück in m2")
Grundstück_m2 = tk.Entry(window)
labelListboxWohnfläche = tk.Label(window, text="Wohnfläche in m2")
Wohnfläche_m2 = tk.Entry(window)
labelListboxBaujahr = tk.Label(window, text="Baujahr")
Baujahr = tk.Entry(window)
ausgabe = tk.Label(window)


#Tabellen: 
BundK # Bundesland und Kostenfaktor
SLundK # StadtvsLand und Kostenfaktor
AundK # Ausstattung und Kostenfaktor
HundK # Hausart und Kostenfaktor
WKproPE # Weitere Kostenfaktoren pro Preis und Einheit


# meine Berechnungen:

preis_fallsMakler = float(WKproPE.loc["Makler"])*0.01 # → mal 0.01 um es in % zu konvertieren
preis_fallsDenkmalschutz = float(WKproPE.loc["Denkmalschutz"])*0.01
preis_QM_Grunstück_nachTabelle = float(WKproPE.loc["QM-Grundstück"])   
preis_QM_Wohnfläche_nachTabelle = float(WKproPE.loc["QM-Wohnfläche"])   
    
#-----------------------------------------------------------------------------------------------------------------------------------------------
def berechnen():
    bdl = listbox_Bundesland.get(listbox_Bundesland.curselection()) # → .get() gibt immer ein String zurück
    slk = listbox_StadtvsLand.get(listbox_StadtvsLand.curselection())# mylistbox.curselection private function von get bei Listbox
    ak = listbox_Ausstattung.get(listbox_Ausstattung.curselection())
    ha = listbox_Hausart.get(listbox_Hausart.curselection())
    Gm2 = float(Grundstück_m2.get())
    berechnung_Grundstück = Gm2 * preis_QM_Grunstück_nachTabelle
    WohnFm2 = float(Wohnfläche_m2.get()) 
    berechnung_Wohnfläche = WohnFm2 * preis_QM_Wohnfläche_nachTabelle
    Baujahrkosten = (float(Baujahr.get()) - 2022) * (float(WKproPE.loc["Baujahr"])/100)    
    flächegesamt = berechnung_Grundstück + berechnung_Wohnfläche - Baujahrkosten 
    ergebnis = round(flächegesamt * float(BundK.loc[bdl]) * float(SLundK.loc[slk]) * float(AundK.loc[ak]) * float(HundK.loc[ha]))
    
    def mitMakler_oderOhne(x):
        if var_Makler.get() == 1:
            mitMakler = x*preis_fallsMakler
            return mitMakler
        else:
            mitMakler = 0
            return mitMakler
    def mitDSchutz_oderOhne(y):
        if var_Makler.get() == 1:
            mitDenkmalschutz = y*preis_fallsDenkmalschutz
            return mitDenkmalschutz
        else:
            mitDenkmalschutz = 0
            return mitDenkmalschutz
        
    ende_ergebnis = ergebnis + mitMakler_oderOhne(ergebnis) + mitDSchutz_oderOhne(ergebnis)
    ausgabe.configure(text=f"ihr zukunftiges Haus wird {ende_ergebnis}€ kosten")
#------------------------------------------------------------------------------------------------------------------------------------------------

#meine Variabeln für meine Buttons:
var_Makler = tk.IntVar()
var_Denkmalschutz = tk.IntVar()
var_Bundesland = tk.Variable(value = list(BundK.index))
var_StadtvsLand = tk.Variable(value = list(SLundK.index))
var_Ausstattung = tk.Variable(value = list(AundK.index))
var_Hausart = tk.Variable(value = list(HundK.index))
var_weitereKosten = tk.Variable(value = list(WKproPE.index))


# o que eu escolho passa entao para a variavel listbox_Bundesland zB, valor esse determinado pelos itens 
#q eu add à Listbox através do meu listvariable, que estao em var_Bundesland

def resetFunktion():
    var_Makler.set(0)
    var_Denkmalschutz.set(0)




#Erstellung meiner Buttons:
labelListboxBundesland =tk.Label(window, text="Wählen Sie bitte ein Bundesland aus")
listbox_Bundesland = tk.Listbox(window, listvariable = var_Bundesland, height=2, selectmode=tk.EXTENDED, exportselection = 0)

labelListboxStadtvsLand =tk.Label(window, text="Wählen Sie die Wohnortart")
listbox_StadtvsLand = tk.Listbox(window, listvariable = var_StadtvsLand, height=1, selectmode=tk.EXTENDED, exportselection = 0)

labelListboxAusstattung =tk.Label(window, text="Wählen Sie bitte die Ausstattungsform aus")
listbox_Ausstattung = tk.Listbox(window, listvariable = var_Ausstattung, height=2, selectmode=tk.EXTENDED, exportselection = 0)

labelListboxHausart =tk.Label(window, text="Wählen Sie bitte die Hausart aus")
listbox_Hausart = tk.Listbox(window, listvariable = var_Hausart, height=2, selectmode=tk.EXTENDED, exportselection = 0)

Radiobutton_Makler = tk.Radiobutton(window, text="Makler", variable = var_Makler, value = 1)                            
Radiobutton_Denkmalschutz = tk.Radiobutton(window, text="Denkmalschutz", variable = var_Denkmalschutz, value = 1)

ErgebnisButton = tk.Button(window, text="Hauspreis", command = berechnen)
ResetButton = tk.Button(window, text="Reset Makler und Denkmalschutz", command=resetFunktion)

# alles ins Window
labelListboxGrundstück.pack()
Grundstück_m2.pack()
labelListboxWohnfläche.pack()
Wohnfläche_m2.pack()
labelListboxBaujahr.pack()
Baujahr.pack()
ausgabe.pack()

labelListboxBundesland.pack()
listbox_Bundesland.pack(expand=True, fill=tk.BOTH)

labelListboxStadtvsLand.pack()
listbox_StadtvsLand.pack(expand=True, fill=tk.BOTH)

labelListboxAusstattung.pack()
listbox_Ausstattung.pack(expand=True, fill=tk.BOTH)

labelListboxHausart.pack()
listbox_Hausart.pack(expand=True, fill=tk.BOTH)

Radiobutton_Makler.pack()
Radiobutton_Denkmalschutz.pack()

ErgebnisButton.pack()
ResetButton.pack()

#Los!
tk.mainloop()
# Out:
# C:\Users\hhhme\AppData\Local\Temp\ipykernel_13948\3707916767.py:29: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   preis_fallsMakler = float(WKproPE.loc["Makler"])*0.01 # → mal 0.01 um es in % zu konvertieren
# C:\Users\hhhme\AppData\Local\Temp\ipykernel_13948\3707916767.py:30: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   preis_fallsDenkmalschutz = float(WKproPE.loc["Denkmalschutz"])*0.01
# C:\Users\hhhme\AppData\Local\Temp\ipykernel_13948\3707916767.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   preis_QM_Grunstück_nachTabelle = float(WKproPE.loc["QM-Grundstück"])
# C:\Users\hhhme\AppData\Local\Temp\ipykernel_13948\3707916767.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   preis_QM_Wohnfläche_nachTabelle = float(WKproPE.loc["QM-Wohnfläche"])
